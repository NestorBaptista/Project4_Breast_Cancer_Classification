# %% [markdown]
# #Dependencies

# %%
#Importing Dependencies
import pandas as pd
from google.colab import files

# %% [markdown]
# #Dicom File

# %%
# Use files.upload() to manually upload a file (decomment)
# files.upload()

# %%
# file_name = "/content/dicom_info.csv"
# dicom_info_df = pd.read_csv(file_name)
# dicom_info_df.head(1)
# Out:
#                                            file_path  \
# 0  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.12930...
#
#                                           image_path  AccessionNumber  \
# 0  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.129308...              NaN
#
#    BitsAllocated  BitsStored BodyPartExamined  Columns  ContentDate  \
# 0             16          16           BREAST      351     20160426
#
#    ContentTime ConversionType  ...  \
# 0   131732.685            WSD  ...
#
#    SecondaryCaptureDeviceManufacturerModelName  SeriesDescription  \
# 0                                       MATLAB     cropped images
#
#                                    SeriesInstanceUID SeriesNumber  \
# 0  1.3.6.1.4.1.9590.100.1.2.129308726812851964007...            1
#
#   SmallestImagePixelValue  SpecificCharacterSet   StudyDate StudyID  \
# 0                   23078            ISO_IR 100  20160720.0    DDSM
#
#                                     StudyInstanceUID  StudyTime
# ...

# %%
# # Extracting the desired part from the PatientID column and creating a new column
# df['ExtractedPatientID'] = df['PatientID'].str.extract(r'_P_(\d+)_')

# df['ExtractedPatientID'] = 'P_' + df['ExtractedPatientID']

# # Printing the resulting DataFrame
# print(df['ExtractedPatientID'])
# Out:
# 0        P_01265
# 1        P_01754
# 2        P_00232
# 3        P_00562
# 4            NaN
#           ...
# 10232    P_01864
# 10233    P_00979
# 10234    P_01461
# 10235    P_00314
# 10236    P_00314
# Name: ExtractedPatientID, Length: 10237, dtype: object

# %% [markdown]
# #CODE STARTS HERE

# %%
file_names = ["/content/mass_case_description_test_set.csv", "/content/mass_case_description_train_set.csv" ]
df = pd.concat([pd.read_csv(file) for file in file_names])
df.head()
# Out:
#   patient_id  breast_density left or right breast image view  abnormality id  \
# 0    P_00016               4                 LEFT         CC               1
# 1    P_00016               4                 LEFT        MLO               1
# 2    P_00017               2                 LEFT         CC               1
# 3    P_00017               2                 LEFT        MLO               1
# 4    P_00032               3                RIGHT         CC               1
#
#   abnormality type mass shape   mass margins  assessment  pathology  subtlety  \
# 0             mass  IRREGULAR     SPICULATED           5  MALIGNANT         5
# 1             mass  IRREGULAR     SPICULATED           5  MALIGNANT         5
# 2             mass      ROUND  CIRCUMSCRIBED           4  MALIGNANT         4
# 3             mass      ROUND    ILL_DEFINED           4  MALIGNANT         4
# 4             mass      ROUND       OBSCURED           0     BENIGN         2
#
# ...

# %%
# Splitting the 'image file path' column based on '/' and adding the extracted string to a new 'path' column
df['folder_path'] = df['image file path'].str.split('/').str[2]

# Drop unnecessary columns
df = df.drop(['image file path', 'cropped image file path', 'ROI mask file path'], axis=1)
df.head()
# Out:
#   patient_id  breast_density left or right breast image view  abnormality id  \
# 0    P_00016               4                 LEFT         CC               1
# 1    P_00016               4                 LEFT        MLO               1
# 2    P_00017               2                 LEFT         CC               1
# 3    P_00017               2                 LEFT        MLO               1
# 4    P_00032               3                RIGHT         CC               1
#
#   abnormality type mass shape   mass margins  assessment  pathology  subtlety  \
# 0             mass  IRREGULAR     SPICULATED           5  MALIGNANT         5
# 1             mass  IRREGULAR     SPICULATED           5  MALIGNANT         5
# 2             mass      ROUND  CIRCUMSCRIBED           4  MALIGNANT         4
# 3             mass      ROUND    ILL_DEFINED           4  MALIGNANT         4
# 4             mass      ROUND       OBSCURED           0     BENIGN         2
#
# ...

# %%
df.dtypes
# Out:
# patient_id              object
# breast_density           int64
# left or right breast    object
# image view              object
# abnormality id           int64
# abnormality type        object
# mass shape              object
# mass margins            object
# assessment               int64
# pathology               object
# subtlety                 int64
# folder_path             object
# dtype: object

# %%
# List of columns to check for blanks
columns_to_check = ['patient_id', 'breast_density', 'left or right breast',
                    'image view', 'abnormality id', 'abnormality type',
                    'mass shape', 'mass margins', 'assessment',
                    'pathology', 'subtlety', 'folder_path']

# Check for blanks in specified columns
blanks = df[columns_to_check].applymap(lambda x: isinstance(x, (str, bytes)) and x.isspace())

# Check if any blanks exist in the specified columns
if blanks.any().any():
    print("There are blanks in the specified columns.")
else:
    print("There are no blanks in the specified columns.")
# Out:
# There are no blanks in the specified columns.
